# %%
#creating pythin datafram

import pandas as pd

data='/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Module_6_Introduction_to_Machine_Learning_with_Python/prisoners.csv'

df=pd.read_csv(data)

df.head(6)
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
# 5                Goa  2013                                                  7
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
# 5                                             0
#
#    No. of Inmates benefitted by Higher Education  \
# ...

# %%
#pandas normal operations to see size and shape of dataframe

df.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# ...

# %%
>>> df.shape
#(rows,columns)
>>> df.index
#Describe index
>>> df.columns
#Describe DataFrame columns 
>>> df.info()
#Info on DataFrame
>>> df.count()
#Number of non-NA values

>>> df.mean()

>>> df.median()

# %%
df.shape
# Out:
# (35, 6)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'YEAR', 'No. of Inmates benefitted by Elementary Education',
#        'No. of Inmates benefitted by Adult Education',
#        'No. of Inmates benefitted by Higher Education',
#        'No. of Inmates benefitted by Computer Course'],
#       dtype='object')

# %%
df.count()
# Out:
# STATE/UT                                             35
# YEAR                                                 35
# No. of Inmates benefitted by Elementary Education    35
# No. of Inmates benefitted by Adult Education         35
# No. of Inmates benefitted by Higher Education        35
# No. of Inmates benefitted by Computer Course         35
# dtype: int64

# %%
df.dtypes
# Out:
# STATE/UT                                             object
# YEAR                                                  int64
# No. of Inmates benefitted by Elementary Education     int64
# No. of Inmates benefitted by Adult Education          int64
# No. of Inmates benefitted by Higher Education         int64
# No. of Inmates benefitted by Computer Course          int64
# dtype: object

# %%
#Making new dataframe from existing dataframe

df_new=df[['STATE/UT','YEAR','No. of Inmates benefitted by Elementary Education']]

df_new.head(5)
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664

# %%
#sorting dataframe

  
# sorting data frame by value in ascending order
df_sorted=df_new.sort_values("No. of Inmates benefitted by Elementary Education", axis = 0, ascending = True) 
  
# display 
df_sorted
# Out:
#              STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education
# 17            Mizoram  2013                                                  0
# 22             Sikkim  2013                                                  0
# 30       D & N Haveli  2013                                                  0
# 29         Chandigarh  2013                                                  0
# 34        Pondicherry  2013                                                  0
# 31        Daman & Diu  2013                                                  0
# 33        Lakshadweep  2013                                                  0
# 15            Manipur  2013                                                  0
# 1   Arunachal Pradesh  2013                                                  0
# 18           Nagaland  2013                                                  0
# 16          Meghalaya  2013                                                  1
# ...

# %%
df_sorted=df_new.sort_values("No. of Inmates benefitted by Elementary Education", axis = 0, ascending = False) 
  
# display 
df_sorted
# Out:
#              STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education
# 0      Andhra Pradesh  2013                                               9480
# 25      Uttar Pradesh  2013                                               7876
# 10          Jharkhand  2013                                               3008
# 6             Gujarat  2013                                               2310
# 27        West Bengal  2013                                               2023
# 13     Madhya Pradesh  2013                                               1978
# 3               Bihar  2013                                               1693
# 4         Chhatisgarh  2013                                               1664
# 32              Delhi  2013                                               1458
# 7             Haryana  2013                                               1131
# 21          Rajasthan  2013                                               1050
# ...

# %%
df_sorted=df_new.sort_values(by=["No. of Inmates benefitted by Elementary Education"], axis = 0, ascending = False) 
  
# display 
df_sorted 
#final_df = df.sort_values(by=['2'], ascending=False)

'''
If you want to sort by two columns, pass a list of column labels 
to sort_values with the column labels ordered according to sort priority. 
If you use df.sort_values(['2', '0']), the result would be sorted by column 2 then column 0
'''
# Out:
#              STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education
# 0      Andhra Pradesh  2013                                               9480
# 25      Uttar Pradesh  2013                                               7876
# 10          Jharkhand  2013                                               3008
# 6             Gujarat  2013                                               2310
# 27        West Bengal  2013                                               2023
# 13     Madhya Pradesh  2013                                               1978
# 3               Bihar  2013                                               1693
# 4         Chhatisgarh  2013                                               1664
# 32              Delhi  2013                                               1458
# 7             Haryana  2013                                               1131
# 21          Rajasthan  2013                                               1050
# ...

# %%
#filtering pandas datafarme on multiple value

df_sorted.head(5)


# load pandas
import pandas as pd
data_url = 'http://bit.ly/2cLzoxH'
# read data from url as pandas dataframe
gapminder = pd.read_csv(data_url)
print(gapminder.head(3))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710

# %%
#1. How to Select Rows of Pandas Dataframe Based on a Single Value of a Column?

# does year equals to 2002?
# is_2002 is a boolean variable with True or False in it
is_2002 =  gapminder['year']==2002
print(is_2002.head())

'''
0    False
1    False
2    False
3    False
4    False
'''

# filter rows for year 2002 using  the boolean variable
gapminder_2002 = gapminder[is_2002]
print(gapminder_2002.shape)

'''
(142, 6)

'''
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: year, dtype: bool
# (142, 6)
# '\n(142, 6)\n\n'

# %%
gapminder_2002.head(30)
# Out:
#                       country  year           pop continent  lifeExp  \
# 10                Afghanistan  2002  2.526840e+07      Asia   42.129
# 22                    Albania  2002  3.508512e+06    Europe   75.651
# 34                    Algeria  2002  3.128714e+07    Africa   70.994
# 46                     Angola  2002  1.086611e+07    Africa   41.003
# 58                  Argentina  2002  3.833112e+07  Americas   74.340
# 70                  Australia  2002  1.954679e+07   Oceania   80.370
# 82                    Austria  2002  8.148312e+06    Europe   78.980
# 94                    Bahrain  2002  6.563970e+05      Asia   74.795
# 106                Bangladesh  2002  1.356568e+08      Asia   62.013
# 118                   Belgium  2002  1.031197e+07    Europe   78.320
# 130                     Benin  2002  7.026113e+06    Africa   54.406
# 142                   Bolivia  2002  8.445134e+06  Americas   63.883
# 154    Bosnia and Herzegovina  2002  4.165416e+06    Europe   74.090
# ...

# %%
# filter rows for year 2002 using  the boolean expression
gapminder_2002 = gapminder[gapminder['year']==2002]
print(gapminder_2002.shape)
# Out:
# (142, 6)

# %%
#2. How to Select Rows of Pandas Dataframe Whose Column Value Does NOT Equal a Specific Value?

# filter rows for year does not equal to 2002
gapminder_not_2002 = gapminder[gapminder.year != 2002]
gapminder_not_2002 = gapminder[gapminder['year']!=2002]
gapminder_not_2002.shape

#(1562, 6)
# Out:
# (1562, 6)

# %%
#3. How to Select Rows of Pandas Dataframe Whose Column Value is NOT NA/NAN?

# filter out rows ina . dataframe with column year values NA/NAN
gapminder_no_NA = gapminder[gapminder.year.notnull()]

gapminder_no_NA.head(5)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
#4. How to Select Rows of Pandas Dataframe Based on a list?

#To select rows whose column value is in list 
years = [1952, 2007]
gapminder.year.isin(years)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12       True
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23       True
# 24       True
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679     True
# 1680     True
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691     True
# 1692     True
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698    False
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703     True
# ...

# %%
gapminder_years= gapminder[gapminder.year.isin(years)]
gapminder_years.shape
#(284, 6)
# Out:
# (284, 6)

# %%
#5. How to Select Rows of Pandas Dataframe Based on Values NOT in a list?

continents = ['Asia','Africa', 'Americas', 'Europe']
gapminder_Ocean = gapminder[~gapminder.continent.isin(continents)]
gapminder_Ocean.shape 
#(24,6)
# Out:
# (24, 6)

# %%
#6. How to Select Rows of Pandas Dataframe using Multiple Conditions?

#gapminder[~gapminder.continent.isin(continents) & gapminder.year.isin(years)]


#df_woman_With_phd = df[(df['Gender']==0) & (df['PhD']==1)]
#df_zero_inmates = df[(df['No. of Inmates benefitted by Elementary Education'] ==0) & (df['No. of Inmates benefitted by Adult Education'] ==0) & (df['No. of Inmates benefitted by Higher Education'] ==0) & (df['No. of Inmates benefitted by Computer Course'] ==0)]

# %%
#7 adding a news column in the end with sum of other coums 

'''


"""
In [37]:  df = pd.DataFrame({"A":[1,2,3],"B":[4,6,9]})

In [38]: df
Out[38]:
   A  B
0  1  4
1  2  6
2  3  9

In [39]: df['C']=df.loc[:,['A','B']].sum(axis=1)

In [40]: df
Out[40]:
   A  B   C
0  1  4   5
1  2  6   8
2  3  9  12

"""

df['total_benefitted'] =  df[['No. of Inmates benefitted by Elementary Education', 'No. of Inmates benefitted by Adult Education',
                             'No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course']].sum(axis=1)


df.head(5)


'''

# %%
#8. Create a new row - “totals” that is the sum of all inmates benefitted through each mode across all states.

df.loc["totals"] = df[['No. of Inmates benefitted by Elementary Education', 'No. of Inmates benefitted by Adult Education',
                             'No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Computer Course','total_benefitted']].sum()

# %%
#9 How to Get Unique Values from a Column in Pandas Data Frame?

#Load gapminder data set

# import pandas as pd
import pandas as pd
# software carpentry url for gapminder data
gapminder_csv_url ='http://bit.ly/2cLzoxH'
# load the data with pd.read_csv
gapminder = pd.read_csv(gapminder_csv_url)

# %%
# check the data frame info
print(gapminder.info())

'''
class 'pandas.core.frame.DataFrame'&gt;
RangeIndex: 1704 entries, 0 to 1703
Data columns (total 6 columns):
country      1704 non-null object
year         1704 non-null int64
pop          1704 non-null float64
continent    1704 non-null object
lifeExp      1704 non-null float64
gdpPercap    1704 non-null float64
dtypes: float64(3), int64(1), object(2)
memory usage: 79.9+ KB

'''

# %%
gapminder['continent'].unique()
#array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

'''
gapminder['continent'].unique().tolist()
['Asia', 'Europe', 'Africa', 'Americas', 'Oceania']

'''

'''
len(gapminder['country'].unique().tolist())
'''

# %%
# unique values with drop_duplicates
gapminder.continent.drop_duplicates()

'''
0         Asia
12      Europe
24      Africa
48    Americas
60     Oceania
Name: continent, dtype: object

'''

# %%
#How to Filter a Pandas Dataframe Based on Null Values of a Column?

df = pd.DataFrame({'Last_Name': ['Smith', None, 'Brown'], 
                   'First_Name': ['John', 'Mike', 'Bill'],
                   'Age': [35, 45, None]})


>df.Last_Name.notnull()
0     True
1    False
2     True
Name: Last_Name, dtype: bool

#We can use this boolean series to filter the dataframe so that it keeps the rows with no missing data for the column ‘Last_Name’.


>df[df.Last_Name.notnull()]
    Age First_Name  Last_Name
0   35.0    John    Smith
2   NaN Bill    Brown

# %%
#How to filter out all rows with missing values?


# drop rows with missing value
>df.dropna()
        Age First_Name  Last_Name
0   35.0    John    Smith




Note that dropna() drops out all rows containing missing data. In this case there is only one row with 
no missing values. By default, dropna() drop rows with missing values. If you want to drop the columns with missing values, we can specify axis =1

#drop column with missing value
>df.dropna(axis=1)
    First_Name
0   John
1   Mike
2   Bill

# %%
#Filtering Rows with Pandas query(): Example 1
gapminder.query('country=="United States"').head()

#Filtering Rows with Pandas query(): Example 2
gapminder.query('year==1952').head()


#Filtering Rows with Pandas query(): Example 3

gapminder.query('country=="United States" & year > 1996')


#Filtering Rows with Pandas query(): Example 4
gapminder.query('country in ["United States", "United Kingdom"] & year > 2000')

# %%
#Pandas Group By 

n_by_state = df.groupby("state")["last_name"].count()
n_by_state.head(10)


#Here’s an example of grouping jointly on two columns, which finds the count of 
#Congressional members broken out by state and then by gender:

df.groupby(["state", "gender"])["last_name"].count()

'''
state  gender
AK     M          16
AL     F           3
       M         203
AR     F           5
       M         112
                ...
WI     M         196
WV     F           1
       M         119
WY     F           2
       M          38
Name: last_name, Length: 104, dtype: int64
'''

 # Don't sort results by the sort keys
df.groupby("state", sort=False)["last_name"].count()

'''
state
DE      97
VA     432
SC     251
MD     305
PA    1053
      ...
AK      16
PI      13
VI       4
GU       4
AS       2
Name: last_name, Length: 58, dtype: int64

'''

# %%
df.groupby(['Fruit','Name'])['Number'].sum().reset_index()

# %%
df.groupby(['Fruit','Name'])['Number'].sum()


'''
df.set_index(['Fruit','Name']).sum(level=[0,1])
Out[175]: 
               Number
Fruit   Name         
Apples  Bob        16
        Mike        9
        Steve      10
Oranges Bob        67
        Tom        15
        Mike       57
        Tony        1
Grapes  Bob        35
        Tom        87
        Tony       15
'''

# %%
# creating pandas dataframe 


import pandas as pd

df = pd.read_csv(
    "groupby-data/airqual.csv",
    parse_dates=[["Date", "Time"]],
    na_values=[-200],
    usecols=["Date", "Time", "CO(GT)", "T", "RH", "AH"]
).rename(
    columns={
        "CO(GT)": "co",
        "Date_Time": "tstamp",
        "T": "temp_c",
        "RH": "rel_hum",
        "AH": "abs_hum",
    }
).set_index("tstamp")

# %%
>>> df.index.min()
Timestamp('2004-03-10 18:00:00')
>>> df.index.max()
Timestamp('2005-04-04 14:00:00')

# %%
#1. Find the highest rated movie in the “Quest” story type.

#df_2011_data_month_Amount=df_2011_data[['Month','Amount']]


df_quest=df[['Movie','Story','RottenTomatoes','AudienceScore']]

#df_woman_With_phd = df[(df['Gender']==0) & (df['PhD']==1)]

df_quest_stry=df_quest[(df['Story'])=='Quest']

#print(df_quest_stry.head(5))

df_quest_stry.sort_values(by='RottenTomatoes', ascending=False).head(5)

# %%
#2. Find the genre in which there has been the greatest number of movie releases

#df.head(5)
#https://realpython.com/pandas-groupby/

df_gen_movies=df[['Movie','Genre']]

df_gen_movies.head(5)

#df.dtypes

df_gen_movies_COUNT = df.groupby("Genre")["Movie"].count().sort_values(ascending=False)

df_gen_movies_COUNT.head(10)

# %%
#3. Print the names of the top five movies with the costliest budgets.

#df.head(5)

df_movies_budget=df[['Movie','Budget']]

#df_movies_budget.head(5)


#df_movies_budget.groupby(['Movie']).sum().head(5)

df_new=df_movies_budget.groupby(['Movie'])['Budget'].sum().sort_values(ascending=False)



'''
Movie
Pirates of the Caribbean: At World's End    300.0
Tangled                                     260.0
Spider-Man 3                                258.0
John Carter                                 250.0
Harry Potter and the Half-Blood Prince      250.0

'''

df_new.head(5)

# %%
'''
5.1: From the raw data below create a data frame 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'], 'age': [42, 52, 36, 24, 73],
'preTestScore': [4, 24, 31, ".", "."],
'postTestScore': ["25,000", "94,000", 57, 62, 70]

'''

data={'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
      'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'], 
      'age': [42, 52, 36, 24, 73],
      'preTestScore': [4, 24, 31, ".", "."],
      'postTestScore': ["25,000", "94,000", 57, 62, 70]
     }



df=pd.DataFrame(data)

df

# %%
#5.2: Save the dataframe into a csv file as example.csv

df.to_csv(r'/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Class_5_Data_Manipulation/574_m5_datasets_v3.0/example.csv', index = False)

# %%
#5.4: Read the example.csv without column heading

data='/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Class_5_Data_Manipulation/574_m5_datasets_v3.0/example.csv'

df_new=pd.read_csv(data, header = None)

df_new.head(6)

# %%
#Question 5: Read the example.csv and make the index columns as 'First Name’ and 'Last Name'

data='/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Class_5_Data_Manipulation/574_m5_datasets_v3.0/example.csv'

df_new=pd.read_csv(data).set_index(['first_name','last_name'])

df_new.head(6)

# %%
#5.7: Read the dataframe by skipping first 3 rows and print the data frame

data='/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Class_5_Data_Manipulation/574_m5_datasets_v3.0/example.csv'

#df_new=pd.read_csv(data,skiprows=[1,2,3])

df_new=pd.read_csv(data,skiprows=3)
df_new.head(6)

# %%
#5.6: Print the data frame in a Boolean form as True or False. True for Null/ NaN values and false for non-null values

'''
dataset5=pd.read_csv(file_path)
df5=pd.DataFrame(dataset5)
# print df5.isnull()
'''

data='/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Class_5_Data_Manipulation/574_m5_datasets_v3.0/example.csv'

df_new=pd.read_csv(data)

print(df_new.head(6))

'''
first_name	last_name	age	preTestScore	postTestScore
0	Jason	Miller	42	4	25,000
1	Molly	Jacobson	52	24	94,000
2	Tina	.	36	31	57
3	Jake	Milner	24	.	62
4	Amy	Cooze	73	.	70

'''

print(df_new.isnull())

# %%
#6.1: From the raw data below create a Pandas Series 'Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'

import numpy as np

data=['Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat']

#data
#df

df=pd.Series(data)

df

# %%
#a) Print all elements in lower case

df=pd.Series(data).str.lower()

df

# %%
#b) Print all the elements in upper case 

df=pd.Series(data).str.upper()

df

# %%
#c) Print the length of all the elements

df=pd.Series(data).str.len()

df

# %%
'''
6.2: From the raw data below create a Pandas Series
' Atul', 'John ', ' jack ', 'Sam'


c) Print all the elements after removing spaces from the right only

'''

# a) Print all elements after stripping spaces from the left and right 
data=[' Atul', 'John ', ' jack ', 'Sam']

df1=pd.Series(data).str.strip()

#
print(df1)


# b) Print all the elements after removing spaces from the left only

df2=pd.Series(data).str.rstrip()

print(df2)


# c) Print all the elements after removing spaces from the right only

df3=pd.Series(data).str.lstrip()

print(df3)

# %%
#handling null values in pandas df

import pandas as pd 
  
# making data frame from csv file 
nba = pd.read_csv("nba.csv") 
  
nba 

# replacing na values in college with No college 
nba["College"].fillna("No College", inplace = True) 
  
nba

# %%
#Count the Null Columns

train = pd.read_csv("train.csv")
null_columns=train.columns[train.isnull().any()]
train[null_columns].isnull().sum()

'''
LotFrontage      259
Alley           1369
MasVnrType         8
MasVnrArea         8
BsmtQual          37
BsmtCond          37
BsmtExposure      38
BsmtFinType1      37
BsmtFinType2      38
Electrical         1
FireplaceQu      690
GarageType        81
GarageYrBlt       81
GarageFinish      81
GarageQual        81
GarageCond        81
PoolQC          1453
Fence           1179
MiscFeature     1406
dtype: int64
'''

#Single Column Is Null

print(train[train["Electrical"].isnull()][null_columns])


#All Null Columns

print(train[train.isnull().any(axis=1)][null_columns].head())

#
 importing pandas package  
import pandas as pd  
    
# making data frame from csv file  
data = pd.read_csv("employees.csv")  
  
# filling a null values using fillna()  
data["Gender"].fillna("No Gender", inplace = True)  
  
data 


#Now we are going to replace the all Nan value in the data frame with -99 value.

import pandas as pd  
    
# making data frame from csv file  
data = pd.read_csv("employees.csv")  
    
# will replace  Nan value in dataframe with value -99   
data.replace(to_replace = np.nan, value = -99)

# %%
#Now we drop rows with at least one Nan value (Null value)

filter_none
brightness_4
# importing pandas as pd 
import pandas as pd 
  
# importing numpy as np 
import numpy as np 
  
# dictionary of lists 
dict = {'First Score':[100, 90, np.nan, 95], 
        'Second Score': [30, np.nan, 45, 56], 
        'Third Score':[52, 40, 80, 98], 
        'Fourth Score':[np.nan, np.nan, np.nan, 65]} 
  
# creating a dataframe from dictionary 
df = pd.DataFrame(dict) 
  
# using dropna() function   
df.dropna()

# %%
#Now we drop a rows whose all data is missing or contain null values(NaN)

import pandas as pd 
  
# importing numpy as np 
import numpy as np 
  
# dictionary of lists 
dict = {'First Score':[100, np.nan, np.nan, 95], 
        'Second Score': [30, np.nan, 45, 56], 
        'Third Score':[52, np.nan, 80, 98], 
        'Fourth Score':[np.nan, np.nan, np.nan, 65]} 
  
df = pd.DataFrame(dict) 
  
# using dropna() function     
df.dropna(how = 'all')

# %%
Code #4: Dropping Rows with at least 1 null value in CSV file

filter_none
brightness_4
# importing pandas module  
import pandas as pd  
    
# making data frame from csv file  
data = pd.read_csv("employees.csv")  
    
# making new data frame with dropped NA values  
new_data = data.dropna(axis = 0, how ='any')  
    
new_data

# %%
#pandas with database

# import the libraries 
import sqlite3 
import pandas as pd 
  
# create a connection 
con = sqlite3.connect('Diabetes.db') 
  
# read data from SQL to pandas dataframe. 
data = pd.read_sql_query('Select * from Diabetes;', con) 
  
# show top 5 rows 
data.head()


#Slicing of rows

# read the data from sql to pandas dataframe. 
data = pd.read_sql_query('Select * from Diabetes;', con) 
  
# slicing the number of rows  
df1 = data[10:15] 
df1 

#Selecting specific columns

data = pd.read_sql_query('Select * from Diabetes;', con) 
  
# selecting specific columns. 
df2 = data.loc[:, ['Glucose', 'BloodPressure']].head() 
df2 

#Display mean of each column

data = pd.read_sql_query('Select * from Diabetes;', con) 
  
# count number of rows and columns 
data.mean()

# %%
#Python| Pandas dataframe.append()

#Example #1: Create two data frames and append the second to the first one.

# Importing pandas as pd 
import pandas as pd 
  
# Creating the first Dataframe using dictionary 
df1 = df = pd.DataFrame({"a":[1, 2, 3, 4], 
                         "b":[5, 6, 7, 8]}) 
  
# Creating the Second Dataframe using dictionary 
df2 = pd.DataFrame({"a":[1, 2, 3], 
                    "b":[5, 6, 7]}) 
  
# Print df1 
print(df1, "\n") 
  
# Print df2 
df2 


#Now append df2 at the end of df1.

# to append df2 at the end of df1 dataframe 
df1.append(df2)
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
# 0  1  5
# 1  2  6
# 2  3  7

# %%
#Notice the index value of second data frame is maintained in the appended data frame. 
#If we do not want it to happen then we can set ignore_index=True.

df1.append(df2, ignore_index = True)
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
# 4  1  5
# 5  2  6
# 6  3  7

# %%
#Example #2: Append dataframe of different shape.

#For unequal no. of columns in the data frame, non-existent value in one of the dataframe will be filled with NaN values.

# Importing pandas as pd 
import pandas as pd 
  
# Creating the first Dataframe using dictionary 
df1 = pd.DataFrame({"a":[1, 2, 3, 4], 
                    "b":[5, 6, 7, 8]}) 
  
# Creating the Second Dataframe using dictionary 
df2 = pd.DataFrame({"a":[1, 2, 3], 
                    "b":[5, 6, 7],  
                    "c":[1, 5, 4]}) 
  
# for appending df2 at the end of df1 
df1.append(df2, ignore_index = True)
# Out:
# /Users/atul595525/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#    a  b    c
# 0  1  5  NaN
# 1  2  6  NaN
# 2  3  7  NaN
# 3  4  8  NaN
# 4  1  5  1.0
# 5  2  6  5.0
# 6  3  7  4.0

# %%
import pandas as pd
 
def main():
    
    # List of Tuples
    students = [ ('jack', 34, 'Sydeny' , 'Australia') ,
                 ('Riti', 30, 'Delhi' , 'India' ) ,
                 ('Vikas', 31, 'Mumbai' , 'India' ) ,
                 ('Neelu', 32, 'Bangalore' , 'India' ) ,
                 ('John', 16, 'New York' , 'US') ,
                 ('Mike', 17, 'las vegas' , 'US')  ]
    
    #Create a DataFrame object
    dfObj = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['a', 'b', 'c' , 'd' , 'e' , 'f']) 
    
    print("Original Dataframe" , dfObj, sep='\n')
    
 
    print("*****Add row in the dataframe using dataframe.append() ****")   
 
    # Pass the row elements as key value pairs to append() function 
    modDfObj = dfObj.append({'Name' : 'Sahil' , 'Age' : 22} , ignore_index=True)
    
    print("Updated Dataframe" , modDfObj, sep='\n')
 
    # Pass a series in append() to append a row in dataframe  
    modDfObj = dfObj.append(pd.Series(['Raju', 21, 'Bangalore', 'India'], index=dfObj.columns ), ignore_index=True)
 
    print("Updated Dataframe" , modDfObj, sep='\n')
 
    
    print("**** Add multiple rows in the dataframe using dataframe.append() and Series ****")
 
    # List of series  
    listOfSeries = [pd.Series(['Raju', 21, 'Bangalore', 'India'], index=dfObj.columns ) ,
                    pd.Series(['Sam', 22, 'Tokyo', 'Japan'], index=dfObj.columns ) ,
                    pd.Series(['Rocky', 23, 'Las Vegas', 'US'], index=dfObj.columns ) ]
    
    # Pass a list of series to the append() to add multiple rows
    modDfObj = dfObj.append(listOfSeries , ignore_index=True)
 
    print("Updated Dataframe" , modDfObj, sep='\n')
    
    
    print("*****Add a row from one dataframe to other dataframe ****") 
    
    # Create an another dataframe 
    # List of Tuples
    students = [ ('Rahul', 22, 'Sydeny' , 'Australia') ,
                 ('Parul', 23, 'Pune' , 'India')  ]
    
    #Create a DataFrame object
    dfObj2 = pd.DataFrame(students, columns = ['Name' , 'Age', 'City' , 'Country'], index=['a', 'b']) 
    
    print("Another Dataframe" , dfObj2, sep='\n')
 
    # add row at index b from dataframe dfObj2 to dataframe dfObj
    modDfObj = dfObj.append(dfObj2.loc['b'], ignore_index=True)
    
    print("Updated Dataframe" , modDfObj, sep='\n')
    
    print("*****Add a row in the dataframe using loc[] ****")   
    
    # Add a new row at index k with values provided in list
    dfObj.loc['k'] = ['Smriti', 26, 'Bangalore', 'India']
    
    print("Updated Dataframe" , dfObj, sep='\n')
    
    print("*****Add a row in the dataframe at index position using iloc[] ****")
    
    # Add a new row at index position 2 with values provided in list
    dfObj.iloc[2] = ['Smriti', 26, 'Bangalore', 'India']
    
    print("Updated Dataframe" , dfObj, sep='\n')
    
    
 
    
if __name__ == '__main__':
    main()
# Out:
# Original Dataframe
#     Name  Age       City    Country
# a   jack   34     Sydeny  Australia
# b   Riti   30      Delhi      India
# c  Vikas   31     Mumbai      India
# d  Neelu   32  Bangalore      India
# e   John   16   New York         US
# f   Mike   17  las vegas         US
# *****Add row in the dataframe using dataframe.append() ****
# Updated Dataframe
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6  Sahil   22        NaN        NaN
# Updated Dataframe
#     Name  Age       City    Country
# 0   jack   34     Sydeny  Australia
# 1   Riti   30      Delhi      India
# 2  Vikas   31     Mumbai      India
# 3  Neelu   32  Bangalore      India
# 4   John   16   New York         US
# 5   Mike   17  las vegas         US
# 6   Raju   21  Bangalore      India
# ...

# %%
import pandas as pd

data = {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
	'physics': [68, 74, 77, 78],
	'chemistry': [84, 56, 73, 69],
	'algebra': [78, 88, 82, 87]}

	
#create dataframe
df_marks = pd.DataFrame(data)
print('Original DataFrame\n------------------')
print(df_marks)

new_row = {'name':'Geo', 'physics':87, 'chemistry':92, 'algebra':97}
#append row to the dataframe
df_marks = df_marks.append(new_row, ignore_index=True)

print('\n\nNew row added to DataFrame\n--------------------------')
print(df_marks)
# Out:
# Original DataFrame
# ------------------
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87
#
#
# New row added to DataFrame
# --------------------------
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87
# 4   Geo       87         92       97

# %%
#Example #1: Dropping Rows by index label

# importing pandas module 
import pandas as pd 
  
# making data frame from csv file 
data = pd.read_csv("nba.csv", index_col ="Name" ) 
  
# dropping passed values 
data.drop(["Avery Bradley", "John Holland", "R.J. Hunter", 
                            "R.J. Hunter"], inplace = True) 
  
# display 
data

# %%
#Example #2 : Dropping columns with column name

# importing pandas module 
import pandas as pd 
  
# making data frame from csv file 
data = pd.read_csv("nba.csv", index_col ="Name" ) 
  
# dropping passed columns 
data.drop(["Team", "Weight"], axis = 1, inplace = True) 
  
# display 
data

# %%
#df = df.drop(df[(df.score < 50) & (df.score > 20)].index)

#df.drop(df[df.score < 50].index, inplace=True)

# %%
#Example 1: Changing the DataFrame into numpy array by using a method DataFrame.to_numpy(). 

# importing pandas 
import pandas as pd  
   
# reading the csv   
data = pd.read_csv("nba.csv")  
      
data.dropna(inplace = True) 
   
# creating DataFrame form weight column 
gfg = pd.DataFrame(data['Weight'].head()) 
   
# using to_numpy() function 
print(gfg.to_numpy())

# %%
#filter operation on pandas datframe

#2. Which Job Title in Year 2014 has highest mean salary?
import pandas as pd
data='/Users/atul595525/Desktop/learning/Edureka_courses/Python_For_Data_Science/Class_5_Data_Manipulation/574_m5_datasets_v3.0/Salaries.csv'
df=pd.read_csv(data)
selected_data=df.loc[:,['JobTitle','Year','TotalPay']]
#gapminder_2002 = gapminder[gapminder['year']==2002]
selected_data_2014 =  selected_data[selected_data['Year']==2014]
selected_data_2014.head(5)

selected_data_2014.groupby(["JobTitle"])["TotalPay"].mean().sort_values(ascending=False).head(5)

# %%
#4. Which are the top 5 common job in Year 2014 and how much do they cost SFO ?

import pandas as pd
df=pd.read_csv(data)
temp_df=df.loc[:,['Year','JobTitle','TotalPayBenefits','Agency']]
selected_data=temp_df[(temp_df['Year']==2014) & (temp_df['Agency']=='San Francisco')]
#print(selected_data.groupby('JobTitle')['TotalPayBenefits'].nlargest(5))
#df[(df['year'] > 2012) & (df['reports'] < 30)]
selected_data.head(5)

selected_data_NEW=selected_data.groupby(["JobTitle"])["TotalPayBenefits"].sum().sort_values(ascending=False)

selected_data_NEW.head(5)
#print(selected_data.groupby('JobTitle')['TotalPayBenefits'].sum()
